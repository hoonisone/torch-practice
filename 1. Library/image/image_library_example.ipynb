# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import cv2
import matplotlib.image

# %% [markdown]
# # Load

# %%
# Open CV (Numpy)
numpy_image = cv2.imread("sample_image.jpg")   # default로 BRG로 읽어온다
numpy_image = cv2.cvtColor(a, cv2.COLOR_BGR2RGB) # cvtColor()를 통해 RGB로 바꿀 수 있다.

# matplotlib (Numpy)
numpy_image2 = matplotlib.image.imread("sample_image.jpg") # read_only

# PIL (PIL)
pil_image = Image.open("sample_image.jpg")

# %% [markdown]
# # Type

# %%
# Open CV (Numpy)
# matplotlib (Numpy)
print(type(numpy_image))

# PIL (PIL)
print(type(pil_image))
# Out:
# <class 'numpy.ndarray'>
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %% [markdown]
# # Convert

# %%
# (Numpy) -> (PIL)
numpy_to_pil_image = Image.fromarray(numpy_image)
print(type(numpy_to_pil_image))


# (PIL) -> (Numpy)
pil_to_numpy_image = np.array(pil_image)
print(type(pil_to_numpy_image))
# Out:
# <class 'PIL.Image.Image'>
# <class 'numpy.ndarray'>

# %% [markdown]
# # Shape

# %%
# (Numpy)
print("%12s: %s"%("(Numpy)'s shape", numpy_image.shape))
print("%12s: %s"%("(Numpy)'s size", numpy_image.size))

# (PIL)
print("%12s: %s"%("(PIL)'s size", pil_image.size))
# Out:
# (Numpy)'s shape: (1059, 1599, 3)
# (Numpy)'s size: 5080023
# (PIL)'s size: (1599, 1059)

# %% [markdown]
# # Show

# %%
numpy_image.shape
# Out:
# (1059, 1599, 3)

# %%
# cv2.imshow("", numpy_image)      # 실행 하면 멈춤
pil_image.show()        # 새로운 창에서 이미지를 띄워줌
pil_image               # jupyter에서 이미지를 띄워줌
plt.imshow(numpy_image)

# %%
numpy_image = cv2.imread("sample_image.jpg")               # load into (Numpy)
numpy_image = matplotlib.image.imread("sample_image.jpg")  # load into (Numpy)
numpy_image = numpy_image.copy()

plt.imshow(numpy_image)

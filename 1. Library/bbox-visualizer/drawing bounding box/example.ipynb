# %%
# pip install bbox-visualizer

# %%
import bbox_visualizer as bbv
from PIL import Image
path = "sample_image.jpg"
pil_image = Image.open(path)
# image

# %%
import numpy as np
numpy_image = np.array(pil_image)

# %%
bbox = [100, 200, 300, 400]
label = "name"
image = origin_image
image = bbv.draw_rectangle(image, bbox)
image = bbv.add_T_label(image, label, bbox)
# img = bbv.add_label(img, label, bbox, top=True)
Image.fromarray(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [32], line 3
#       1 bbox = [100, 200, 300, 400]
#       2 label = "name"
# ----> 3 image = origin_image
#       4 image = bbv.draw_rectangle(image, bbox)
#       5 image = bbv.add_T_label(image, label, bbox)
#
# NameError: name 'origin_image' is not defined

# %%
# Out:
# <PIL.Image.Image image mode=RGB size=1599x1059>

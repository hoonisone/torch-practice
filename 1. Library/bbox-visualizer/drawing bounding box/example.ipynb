# %% [markdown]
# https://github.com/shoumikchow/bbox-visualizer

# %%
# pip install bbox-visualizer

# %%
import matplotlib
import bbox_visualizer as bbv

# %%
label = "name"
bbox = [100, 200, 300, 400]

image = matplotlib.image.imread("sample_image.jpg")
image = bbv.draw_rectangle(image, bbox)
image = bbv.add_T_label(image, label, bbox)
plt.imshow(image)

# %%
labels = "name"
bboxes = [
    [100, 200, 300, 400],
    [200, 300, 400, 500]
]

image = matplotlib.image.imread("sample_image.jpg")
image = bbv.draw_rectangle(image, bbox)
image = bbv.add_T_label(image, label, bbox)
plt.imshow(image)


image = numpy_image
image = bbv.draw_rectangle(image, bbox)
image = bbv.add_label(image, label, bbox)
plt.imshow(image)
